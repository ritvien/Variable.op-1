# %%
import turtle
b = "black"
g = "gold"


h = turtle.Turtle()
h.pensize(1) 
h.pencolor(b)
h.rt(140)
h.fd(100)
h.rt(40)
h.fillcolor("blue")
h.begin_fill()
h.fd(150)
h.lt(90)
h.fd(100)
h.lt(90)
h.fd(150)
h.lt(90)
h.fd(100)
h.end_fill()
h.rt(50)
h.fillcolor("yellow")
h.begin_fill()
h.fd(100)
h.rt(130)
h.fd(100)
h.rt(50)
h.fd(100)
h.rt(130)
h.fd(100)
h.end_fill()
h.lt(60)
h.fillcolor("red")
h.begin_fill()
h.fd(87)
h.lt(60)
h.fd(87)
h.lt(150)
h.fd(150)
h.end_fill()
h.lt(150)
h.fillcolor("brown")
h.begin_fill()
h.fd(87)
h.rt(110)
h.fd(100)
h.rt(70)
h.fd(87)
h.rt(110)
h.fd(100)
h.end_fill()

#window

h.lt(50)
h.fd(25)
h.pencolor("yellow")
h.lt(130)
h.fd(10)
h.pencolor(b)
h.fillcolor("sky blue")
h.begin_fill()
h.fd(40)
h.rt(130)
h.fd(40)
h.rt(50)
h.fd(40)
h.rt(130)
h.fd(40)
h.end_fill()

#door

h.pencolor("yellow")
h.lt(90)
h.fd(10)
h.pencolor("blue")
h.fd(20)
h.pencolor(b)
h.fillcolor("orange")
h.begin_fill()
h.fd(30)
h.lt(90)
h.fd(80)
h.lt(90)
h.fd(30)
h.lt(90)
h.fd(80)
h.rt(90)
h.end_fill()
h.pencolor("blue")
h.fd(20)

#tree

t = turtle.Turtle()
t.pensize(1)
t.pencolor("sky blue")
t.fd(200)
t.rt(90)
t.fd(50)
t.pencolor(b)
t.fillcolor("brown")
t.begin_fill()
t.fd(70)
t.lt(90)
t.fd(20)
t.lt(90)
t.fd(70)
t.lt(90)
t.fd(20)
t.end_fill()
t.fillcolor("green")
t.begin_fill()
t.fd(30)
t.rt(120)
t.fd(80)
t.rt(120)
t.fd(80)
t.rt(120)
t.fd(80)
t.end_fill()
t.rt(120)
t.fd(80)
t.lt(120)
t.fillcolor("green")
t.begin_fill()
t.fd(40)
t.rt(120)
t.fd(80)
t.rt(120)
t.fd(80)
t.rt(120)
t.fd(80)
t.end_fill()

#sun

s= turtle.Turtle()
s.pencolor("sky blue")
s.goto(150,210)
s.pensize(1)
s.pencolor(b)
s.fillcolor(g)
s.begin_fill()
s.circle(30)
s.end_fill()
s.rt(90)
s.fd(20)
s.bk(20)
s.pencolor(g)
s.bk(60)
s.pencolor(b)
s.bk(20)
s.fd(20)
s.pencolor(g)
s.fd(30)
s.rt(90)
s.fd(30)
s.pencolor(b)
s.fd(20)
s.bk(20)
s.pencolor(g)
s.bk(60)
s.pencolor(b)
s.bk(20)
s.fd(20)
s.pencolor(g)
s.fd(30)
s.rt(45)
s.fd(30)
s.pencolor(b)
s.fd(10)
s.bk(10)
s.pencolor(g)
s.bk(60)
s.pencolor(b)
s.bk(10)
s.fd(10)
s.pencolor(g)
s.fd(30)
s.rt(90)
s.fd(30)
s.pencolor(b)
s.fd(10)
s.bk(10)
s.pencolor(g)
s.bk(60)
s.pencolor(b)
s.bk(10)
turtle.done
# Out:
# <function turtle.mainloop()>
